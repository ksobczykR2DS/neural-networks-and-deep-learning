# %%
import numpy as np
import matplotlib.pyplot as plt
# import mkl

# mkl.set_num_threads(2)
np.random.seed(1234)

# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'
plt.rcParams["figure.figsize"] = [16, 9]

# %% [markdown]
# ### Handy utility functions

# %%
def append_ones(matrix, axis=1):
    return np.concatenate((matrix, np.ones((matrix.shape[0], 1), dtype=np.float32)), axis=axis)

def zeros(*dims):
    return np.zeros(shape=tuple(dims), dtype=np.float32)

def ones(*dims):
    return np.ones(shape=tuple(dims), dtype=np.float32)

def rand(*dims):
    return np.random.rand(*dims).astype(np.float32)

def chunks(seq, size):
    return (seq[pos:pos + size] for pos in range(0, len(seq), size))

def tiles(examples):
    rows_count = examples.shape[0]
    cols_count = examples.shape[1]
    tile_height = examples.shape[2]
    tile_width = examples.shape[3]
    
    space_between_tiles = 2
    img_matrix = np.empty(shape=(rows_count * (tile_height + space_between_tiles) - space_between_tiles,  
                                 cols_count * (tile_width + space_between_tiles) - space_between_tiles))
    img_matrix.fill(np.nan)

    for r in range(rows_count):
        for c in range(cols_count):
            x_0 = r * (tile_height + space_between_tiles)
            y_0 = c * (tile_width + space_between_tiles)
            ex_min = np.min(examples[r, c])
            ex_max = np.max(examples[r, c])
            img_matrix[x_0:x_0 + tile_height, y_0:y_0 + tile_width] = (examples[r, c] - ex_min) / (ex_max - ex_min)
    
    plt.matshow(img_matrix, cmap='gray', interpolation='none')
    plt.axis('off')
    plt.show()

# %% [markdown]
# # MNIST dataset

# %%
import mnist
digits = np.reshape(mnist.train_images()[:12*24], newshape=(12, 24, 28, 28))
tiles(digits)

# %% [markdown]
# # Restricted Boltzmann Machine & Contrastive Divergence algorithm

# %%
def sigmoid(matrix):
    return 1.0 / (1.0 + np.exp(-matrix))

class Rbm:
    def __init__(self, visible_size, hidden_size, learning_rate, momentum):
        self.visible_size = visible_size
        self.hidden_size = hidden_size
        self.learning_rate = learning_rate
        self.momentum = momentum
        
        self.reset()
    
    def reset(self):
        self.W = np.random.normal(scale=0.01, size=(self.visible_size+1, self.hidden_size+1)).astype(np.float32)
        self.W[:, -1] = 0.0
        self.W[-1, :] = 0.0
        self.M = zeros(self.visible_size+1, self.hidden_size+1)

# %%
def reconstruction_error(rbm, minibatch):
    observations_count = minibatch.shape[0]

    hidden = append_ones(zeros(observations_count, rbm.hidden_size))
    hidden[:, :-1] = sigmoid(minibatch @ rbm.W[:, :-1]) > rand(hidden.shape[0], hidden.shape[1] - 1)
    visible = sigmoid(hidden @ rbm.W[:-1, :].T)
    
    error = np.sum((minibatch[:, :-1] - visible) ** 2) / observations_count

    return error

# %%
def train_epoch(rbm, dataset, batch_size):
    batches_limit = dataset.shape[0] / batch_size
    for batch_idx, batch in enumerate(chunks(dataset, batch_size)):
        cdk(rbm, batch)
        if batch_idx % round(batches_limit / 50) == 0: print("#", end="")

def run_training(rbm, dataset, monitoring_set, batch_size, epochs_count):
    for epoch in range(epochs_count):
        print("Epoch {}:".format(epoch),  end="\t")
        
        if epoch == 5:
            rbm.momentum = 0.8

        start_time = time.time()
        train_epoch(rbm, dataset, batch_size)
        elapsed = time.time() - start_time
        
        error = reconstruction_error(rbm, monitoring_set)
        print("\telapsed: {0:>2.2f}s, reconstruction error: {1:>2.2f}".format(elapsed, error))

    print("Training finished!")

# %%
def draw_filters(rbm):
    filters = np.reshape(np.transpose(rbm.W)[:-1, :-1], newshape=(8, -1, 28, 28))
    tiles(filters)

# %% [markdown]
# # 1. RBM Training with momentum

# %%
def cdk(rbm, minibatch, k=1):
    observations_count = minibatch.shape[0]

    positive_visible = minibatch
    positive_hidden = append_ones(zeros(observations_count, rbm.hidden_size))

    negative_visible = append_ones(zeros(observations_count, rbm.visible_size))
    negative_hidden = append_ones(zeros(observations_count, rbm.hidden_size))
    
    # Positive Phase
    positive_hidden_preactivation = positive_visible @ rbm.W[:, :-1] # Slice-out bias for hidden layer
    positive_hidden[:, :-1] = sigmoid(positive_hidden_preactivation)
    
    positive_gradient = positive_visible.T @ positive_hidden / observations_count
    
    # Negative Phase
    negative_hidden[:, :-1] = positive_hidden[:, :-1] > rand(positive_hidden.shape[0],
                                                             positive_hidden.shape[1] - 1)

    negative_visible[:, :-1] = sigmoid(negative_hidden @ rbm.W[:-1, :].T) > rand(negative_visible.shape[0],
                                                                                 negative_visible.shape[1] - 1)

    # Perform k-1 Gibbs's steps as first step has been already taken.
    for _ in range(k-1):
          
        negative_hidden[:, :-1] = sigmoid(negative_visible @ rbm.W[:, :-1]) > rand(negative_hidden.shape[0],
                                                                                   negative_hidden.shape[1] - 1)
        
        negative_visible[:, :-1] = sigmoid(negative_hidden @ rbm.W[:-1, :].T) > rand(negative_visible.shape[0],
                                                                                    negative_visible.shape[1] - 1)
    

    negative_hidden_preactivation = negative_visible @ rbm.W[:, :-1] # Slice-out bias for hidden layer
    negative_hidden[:, :-1] = sigmoid(negative_hidden_preactivation)
    negative_gradient = negative_visible.T @ negative_hidden / observations_count
    
    # Update weights with momentum
    gradient = - positive_gradient + negative_gradient
    momentum_from_previous_step = rbm.momentum * rbm.M
    rbm.M =  momentum_from_previous_step - rbm.learning_rate * gradient
    rbm.W += rbm.M

# %%
import time

DATASET_SIZE = 20000 # 60000 for whole dataset
DIGIT_SIZE = 28

VISIBLE_LAYER_SIZE = DIGIT_SIZE*DIGIT_SIZE
HIDDEN_LAYER_SIZE = 128

mnist_train = mnist.train_images().astype(np.float32) / 255.0
np.random.shuffle(mnist_train)
dataset = np.reshape(mnist_train[:DATASET_SIZE], newshape=(DATASET_SIZE, DIGIT_SIZE*DIGIT_SIZE))
dataset = append_ones(dataset)

monitoring_indexes = np.random.choice(DATASET_SIZE, 256, replace=False)
monitoring_set = dataset[monitoring_indexes]

# %%
BATCH_SIZE = 128
EPOCHS_COUNT = 50

LEARNING_RATE = 0.1
MOMENTUM = 0.5

rbm = Rbm(VISIBLE_LAYER_SIZE, HIDDEN_LAYER_SIZE, LEARNING_RATE, MOMENTUM)
draw_filters(rbm)

run_training(rbm, dataset, monitoring_set, BATCH_SIZE, EPOCHS_COUNT)

draw_filters(rbm)
# Out:
# Epoch 0:	#####################################################	elapsed: 1.90s, reconstruction error: 26.47
# Epoch 1:	#####################################################	elapsed: 1.76s, reconstruction error: 21.38
# Epoch 2:	#####################################################	elapsed: 1.87s, reconstruction error: 18.80
# Epoch 3:	#####################################################	elapsed: 1.81s, reconstruction error: 17.32
# Epoch 4:	#####################################################	elapsed: 1.80s, reconstruction error: 16.27
# Epoch 5:	#####################################################	elapsed: 1.81s, reconstruction error: 15.05
# Epoch 6:	#####################################################	elapsed: 1.79s, reconstruction error: 13.94
# Epoch 7:	#####################################################	elapsed: 1.82s, reconstruction error: 13.31
# Epoch 8:	#####################################################	elapsed: 1.72s, reconstruction error: 12.92
# Epoch 9:	#####################################################	elapsed: 1.78s, reconstruction error: 12.63
# Epoch 10:	#####################################################	elapsed: 1.83s, reconstruction error: 12.10
# Epoch 11:	#####################################################	elapsed: 1.76s, reconstruction error: 11.93
# Epoch 12:	#####################################################	elapsed: 1.84s, reconstruction error: 11.76
# Epoch 13:	#####################################################	elapsed: 1.93s, reconstruction error: 11.60
# Epoch 14:	#####################################################	elapsed: 1.94s, reconstruction error: 11.66
# Epoch 15:	#####################################################	elapsed: 1.97s, reconstruction error: 11.23
# Epoch 16:	#####################################################	elapsed: 1.96s, reconstruction error: 11.30
# Epoch 17:	#####################################################	elapsed: 1.97s, reconstruction error: 11.18
# Epoch 18:	#####################################################	elapsed: 2.04s, reconstruction error: 11.17
# Epoch 19:	#####################################################	elapsed: 1.94s, reconstruction error: 11.02
# Epoch 20:	#####################################################	elapsed: 1.94s, reconstruction error: 10.87
# Epoch 21:	#####################################################	elapsed: 2.00s, reconstruction error: 11.12
# Epoch 22:	#####################################################	elapsed: 2.00s, reconstruction error: 10.78
# Epoch 23:	#####################################################	elapsed: 2.00s, reconstruction error: 10.96
# Epoch 24:	#####################################################	elapsed: 2.05s, reconstruction error: 10.82
# Epoch 25:	#####################################################	elapsed: 2.04s, reconstruction error: 10.81
# Epoch 26:	#####################################################	elapsed: 1.67s, reconstruction error: 10.71
# Epoch 27:	#####################################################	elapsed: 0.82s, reconstruction error: 10.64
# Epoch 28:	#####################################################	elapsed: 0.81s, reconstruction error: 10.60
# Epoch 29:	#####################################################	elapsed: 0.85s, reconstruction error: 10.64
# Epoch 30:	#####################################################	elapsed: 0.95s, reconstruction error: 10.48
# Epoch 31:	#####################################################	elapsed: 0.87s, reconstruction error: 10.59
# Epoch 32:	#####################################################	elapsed: 0.94s, reconstruction error: 10.49
# Epoch 33:	#####################################################	elapsed: 0.84s, reconstruction error: 10.51
# Epoch 34:	#####################################################	elapsed: 0.80s, reconstruction error: 10.53
# Epoch 35:	#####################################################	elapsed: 0.80s, reconstruction error: 10.35
# Epoch 36:	#################################
# C:\Users\ksobc\AppData\Local\Temp\ipykernel_27960\2630183706.py:2: RuntimeWarning: overflow encountered in exp
#   return 1.0 / (1.0 + np.exp(-matrix))
# ####################	elapsed: 0.88s, reconstruction error: 10.48
# Epoch 37:	#####################################################	elapsed: 0.82s, reconstruction error: 10.37
# Epoch 38:	#####################################################	elapsed: 0.72s, reconstruction error: 10.43
# Epoch 39:	#####################################################	elapsed: 0.82s, reconstruction error: 10.23
# Epoch 40:	#####################################################	elapsed: 1.01s, reconstruction error: 10.41
# Epoch 41:	#####################################################	elapsed: 1.06s, reconstruction error: 10.28
# Epoch 42:	#####################################################	elapsed: 1.04s, reconstruction error: 10.23
# Epoch 43:	#####################################################	elapsed: 0.89s, reconstruction error: 10.23
# Epoch 44:	#####################################################	elapsed: 1.04s, reconstruction error: 10.21
# Epoch 45:	#####################################################	elapsed: 1.03s, reconstruction error: 10.30
# Epoch 46:	#####################################################	elapsed: 1.10s, reconstruction error: 10.30
# Epoch 47:	#####################################################	elapsed: 0.95s, reconstruction error: 10.21
# Epoch 48:	#####################################################	elapsed: 0.75s, reconstruction error: 10.20
# Epoch 49:	#####################################################	elapsed: 0.91s, reconstruction error: 10.15
# Training finished!

# %% [markdown]
# # 2. DBN Training

# %%
def propagate_up(dbn, layers_count, visible):
    for i in range(layers_count):
        visible = append_ones(sigmoid(visible @ dbn[i].W[:, :-1]))
    return visible

def propagate_down(dbn, layers_count, hidden):
    for i in reversed(range(layers_count)):
        hidden = append_ones(sigmoid(hidden @ np.transpose(dbn[i].W[:-1, :])))
    return hidden

# %% [markdown]
# ### DBN reconstruction error

# %%
def dbn_reconstruction_error(dbn, layers_count, minibatch):
    propagated_up = propagate_up(dbn, layers_count, minibatch)
    rbm = dbn[layers_count]
    
    error = reconstruction_error(rbm, propagated_up)
    return error

# %% [markdown]
# ### Sampling in Deep Belief Networks

# %%
def sample_rbm(rbm, minibatch, steps):
    observations_count = minibatch.shape[0]

    visible = minibatch
    hidden = append_ones(zeros(observations_count, rbm.hidden_size))
    
    for cd_i in range(steps):
        hidden[:, :-1] = sigmoid(visible @ rbm.W[:, :-1])
        hidden[:, :-1] = (hidden[:, :-1] > rand(observations_count, rbm.hidden_size)).astype(np.float32)
    
        visible[:, :-1] = sigmoid(hidden @ np.transpose(rbm.W[:-1, :]))
        if cd_i < (steps - 1):
            visible[:, :-1] = (visible[:, :-1] > rand(observations_count, rbm.visible_size)).astype(np.float32)

    return visible

# %%
def sample_dbn(dbn, layer_idx, minibatch, steps):
    
    sample = propagate_up(dbn, layer_idx, minibatch)
    sample = sample_rbm(dbn[layer_idx], sample, steps) 
    sample = propagate_down(dbn, layer_idx, sample)
    
    return sample

# %%
def draw_layer_samples(dbn, layer_idx, minibatch, steps=200):
    samples = sample_dbn(dbn, layer_idx, minibatch, steps)
    tiles(np.reshape(samples[:, :-1], newshape=(-1, 16, 28, 28)))

# %% [markdown]
# ### Greedy layer-wise training

# %%
def train_dbn(dbn, layer_idx, dataset, batch_size):
    
    dataset = propagate_up(dbn, layer_idx, dataset)
    
    batches_limit = dataset.shape[0] / batch_size
    for batch_idx, batch in enumerate(chunks(dataset, batch_size)):
        cdk(dbn[layer_idx], batch)
        if batch_idx % round(batches_limit / 50) == 0: print("#", end="")

# %%
BATCH_SIZE = 128
EPOCHS_COUNT = 50

LEARNING_RATE = 0.1
MOMENTUM = 0.5

DBN_HIDDEN_LAYER_SIZE = 200
dbn = [
    Rbm(VISIBLE_LAYER_SIZE, DBN_HIDDEN_LAYER_SIZE, LEARNING_RATE, MOMENTUM),
    Rbm(DBN_HIDDEN_LAYER_SIZE, DBN_HIDDEN_LAYER_SIZE, LEARNING_RATE, MOMENTUM),
    Rbm(DBN_HIDDEN_LAYER_SIZE, DBN_HIDDEN_LAYER_SIZE, LEARNING_RATE, MOMENTUM)
]

for layer_idx in range(len(dbn)):
    print("\nLearning layer {}".format(layer_idx))

    for epoch in range(EPOCHS_COUNT):
        print("Epoch {}:".format(epoch),  end="\t")

        if epoch == 5:
            dbn[layer_idx].momentum = 0.8
        
        start_time = time.time()
        train_dbn(dbn, layer_idx, dataset, BATCH_SIZE)
        elapsed = time.time() - start_time
        
        error = dbn_reconstruction_error(dbn, layer_idx, monitoring_set)
        print("\telapsed: {0:>2.2f}s, reconstruction error: {1:>2.2f}".format(elapsed, error))
    
print("Training finished!")
# Out:
# Learning layer 0
# Epoch 0:	#####################################################	elapsed: 1.46s, reconstruction error: 24.53
# Epoch 1:	#####################################################	elapsed: 2.26s, reconstruction error: 19.26
# Epoch 2:	#####################################################	elapsed: 2.71s, reconstruction error: 16.77
# Epoch 3:	#####################################################	elapsed: 2.64s, reconstruction error: 15.17
# Epoch 4:	#####################################################	elapsed: 2.58s, reconstruction error: 14.09
# Epoch 5:	#####################################################	elapsed: 2.59s, reconstruction error: 12.92
# Epoch 6:	#####################################################	elapsed: 2.40s, reconstruction error: 11.99
# Epoch 7:	#####################################################	elapsed: 2.58s, reconstruction error: 11.33
# Epoch 8:	#####################################################	elapsed: 2.53s, reconstruction error: 10.81
# Epoch 9:	#####################################################	elapsed: 2.61s, reconstruction error: 10.44
# Epoch 10:	#####################################################	elapsed: 2.51s, reconstruction error: 10.42
# Epoch 11:	#####################################################	elapsed: 2.61s, reconstruction error: 10.24
# Epoch 12:	#####################################################	elapsed: 2.67s, reconstruction error: 9.92
# Epoch 13:	#####################################################	elapsed: 2.56s, reconstruction error: 9.76
# Epoch 14:	#####################################################	elapsed: 2.56s, reconstruction error: 9.58
# Epoch 15:	#####################################################	elapsed: 2.55s, reconstruction error: 9.46
# Epoch 16:	#####################################################	elapsed: 2.61s, reconstruction error: 9.38
# Epoch 17:	#####################################################	elapsed: 2.61s, reconstruction error: 9.38
# Epoch 18:	#####################################################	elapsed: 2.54s, reconstruction error: 9.22
# Epoch 19:	#####################################################	elapsed: 2.64s, reconstruction error: 9.06
# Epoch 20:	#####################################################	elapsed: 2.66s, reconstruction error: 9.15
# Epoch 21:	#####################################################	elapsed: 2.55s, reconstruction error: 9.04
# Epoch 22:	#####################################################	elapsed: 2.66s, reconstruction error: 9.12
# Epoch 23:	#####################################################	elapsed: 2.57s, reconstruction error: 8.97
# Epoch 24:	#####################################################	elapsed: 2.59s, reconstruction error: 8.88
# Epoch 25:	#####################################################	elapsed: 2.63s, reconstruction error: 8.87
# Epoch 26:	#####################################################	elapsed: 2.65s, reconstruction error: 8.87
# Epoch 27:	#####################################################	elapsed: 2.68s, reconstruction error: 8.82
# Epoch 28:	#####################################################	elapsed: 2.73s, reconstruction error: 8.64
# Epoch 29:	#####################################################	elapsed: 2.74s, reconstruction error: 8.82
# Epoch 30:	#####################################################	elapsed: 2.70s, reconstruction error: 8.67
# Epoch 31:	#####################################################	elapsed: 2.61s, reconstruction error: 8.62
# Epoch 32:	#####################################################	elapsed: 2.80s, reconstruction error: 8.78
# Epoch 33:	#####################################################	elapsed: 2.76s, reconstruction error: 8.78
# Epoch 34:	#####################################################	elapsed: 2.73s, reconstruction error: 8.52
# Epoch 35:	#####################################################	elapsed: 2.69s, reconstruction error: 8.50
# Epoch 36:	#####################################################	elapsed: 2.73s, reconstruction error: 8.54
# Epoch 37:	#####################################################	elapsed: 2.74s, reconstruction error: 8.47
# Epoch 38:	#####################################################	elapsed: 2.69s, reconstruction error: 8.45
# Epoch 39:	#####################################################	elapsed: 2.74s, reconstruction error: 8.61
# Epoch 40:	#####################################################	elapsed: 2.73s, reconstruction error: 8.49
# Epoch 41:	#####################################################	elapsed: 2.67s, reconstruction error: 8.40
# Epoch 42:	#####################################################	elapsed: 2.19s, reconstruction error: 8.45
# Epoch 43:	#####################################################	elapsed: 1.32s, reconstruction error: 8.24
# Epoch 44:	#####################################################	elapsed: 1.31s, reconstruction error: 8.39
# Epoch 45:	#####################################################	elapsed: 1.37s, reconstruction error: 8.42
# Epoch 46:	#####################################################	elapsed: 1.34s, reconstruction error: 8.43
# Epoch 47:	#####################################################	elapsed: 1.22s, reconstruction error: 8.32
# Epoch 48:	#####################################################	elapsed: 1.31s, reconstruction error: 8.29
# Epoch 49:	#####################################################	elapsed: 1.36s, reconstruction error: 8.46
#
# Learning layer 1
# Epoch 0:	#####################################################	elapsed: 0.63s, reconstruction error: 14.18
# Epoch 1:	#####################################################	elapsed: 0.68s, reconstruction error: 10.82
# Epoch 2:	#####################################################	elapsed: 0.69s, reconstruction error: 9.08
# Epoch 3:	#####################################################	elapsed: 0.72s, reconstruction error: 7.97
# Epoch 4:	#####################################################	elapsed: 0.64s, reconstruction error: 7.39
# Epoch 5:	#####################################################	elapsed: 0.68s, reconstruction error: 6.74
# Epoch 6:	#####################################################	elapsed: 0.48s, reconstruction error: 6.18
# Epoch 7:	#####################################################	elapsed: 0.69s, reconstruction error: 5.72
# Epoch 8:	#####################################################	elapsed: 0.66s, reconstruction error: 5.63
# Epoch 9:	#####################################################	elapsed: 0.61s, reconstruction error: 5.37
# Epoch 10:	#####################################################	elapsed: 0.65s, reconstruction error: 5.23
# Epoch 11:	#####################################################	elapsed: 0.57s, reconstruction error: 5.06
# Epoch 12:	#####################################################	elapsed: 0.58s, reconstruction error: 4.98
# Epoch 13:	#####################################################	elapsed: 0.61s, reconstruction error: 4.83
# Epoch 14:	#####################################################	elapsed: 0.61s, reconstruction error: 4.80
# Epoch 15:	#####################################################	elapsed: 0.64s, reconstruction error: 4.77
# Epoch 16:	#####################################################	elapsed: 0.67s, reconstruction error: 4.66
# Epoch 17:	#####################################################	elapsed: 0.59s, reconstruction error: 4.60
# Epoch 18:	#####################################################	elapsed: 0.57s, reconstruction error: 4.54
# Epoch 19:	#####################################################	elapsed: 0.49s, reconstruction error: 4.61
# Epoch 20:	#####################################################	elapsed: 0.50s, reconstruction error: 4.40
# Epoch 21:	#####################################################	elapsed: 0.52s, reconstruction error: 4.55
# Epoch 22:	#####################################################	elapsed: 0.55s, reconstruction error: 4.32
# Epoch 23:	#####################################################	elapsed: 0.64s, reconstruction error: 4.42
# Epoch 24:	#####################################################	elapsed: 0.60s, reconstruction error: 4.34
# Epoch 25:	#####################################################	elapsed: 0.56s, reconstruction error: 4.21
# Epoch 26:	#####################################################	elapsed: 0.70s, reconstruction error: 4.43
# Epoch 27:	#####################################################	elapsed: 0.59s, reconstruction error: 4.26
# Epoch 28:	#####################################################	elapsed: 0.51s, reconstruction error: 4.30
# Epoch 29:	#####################################################	elapsed: 0.62s, reconstruction error: 4.23
# Epoch 30:	#####################################################	elapsed: 0.65s, reconstruction error: 4.23
# Epoch 31:	#####################################################	elapsed: 0.55s, reconstruction error: 4.18
# Epoch 32:	#####################################################	elapsed: 0.61s, reconstruction error: 4.24
# Epoch 33:	#####################################################	elapsed: 0.64s, reconstruction error: 4.15
# Epoch 34:	#####################################################	elapsed: 0.57s, reconstruction error: 4.13
# Epoch 35:	#####################################################	elapsed: 0.71s, reconstruction error: 4.01
# Epoch 36:	#####################################################	elapsed: 0.58s, reconstruction error: 4.17
# Epoch 37:	#####################################################	elapsed: 0.63s, reconstruction error: 4.19
# Epoch 38:	#####################################################	elapsed: 0.64s, reconstruction error: 4.11
# Epoch 39:	#####################################################	elapsed: 0.53s, reconstruction error: 4.04
# Epoch 40:	#####################################################	elapsed: 0.58s, reconstruction error: 4.14
# Epoch 41:	#####################################################	elapsed: 0.64s, reconstruction error: 4.14
# Epoch 42:	#####################################################	elapsed: 0.74s, reconstruction error: 4.07
# Epoch 43:	#####################################################	elapsed: 0.54s, reconstruction error: 4.23
# Epoch 44:	#####################################################	elapsed: 0.50s, reconstruction error: 4.04
# Epoch 45:	#####################################################	elapsed: 0.43s, reconstruction error: 4.09
# Epoch 46:	#####################################################	elapsed: 0.57s, reconstruction error: 4.07
# Epoch 47:	#####################################################	elapsed: 0.62s, reconstruction error: 4.06
# Epoch 48:	#####################################################	elapsed: 0.64s, reconstruction error: 4.03
# Epoch 49:	#####################################################	elapsed: 0.58s, reconstruction error: 3.93
#
# Learning layer 2
# Epoch 0:	#####################################################	elapsed: 0.67s, reconstruction error: 10.17
# Epoch 1:	#####################################################	elapsed: 0.76s, reconstruction error: 7.46
# Epoch 2:	#####################################################	elapsed: 0.65s, reconstruction error: 6.30
# Epoch 3:	#####################################################	elapsed: 0.56s, reconstruction error: 5.67
# Epoch 4:	#####################################################	elapsed: 0.62s, reconstruction error: 5.09
# Epoch 5:	#####################################################	elapsed: 0.70s, reconstruction error: 4.53
# Epoch 6:	#####################################################	elapsed: 0.71s, reconstruction error: 4.26
# Epoch 7:	#####################################################	elapsed: 0.77s, reconstruction error: 3.92
# Epoch 8:	#####################################################	elapsed: 0.65s, reconstruction error: 3.84
# Epoch 9:	#####################################################	elapsed: 0.57s, reconstruction error: 3.68
# Epoch 10:	#####################################################	elapsed: 1.52s, reconstruction error: 3.64
# Epoch 11:	#####################################################	elapsed: 0.55s, reconstruction error: 3.44
# Epoch 12:	#####################################################	elapsed: 0.57s, reconstruction error: 3.34
# Epoch 13:	#####################################################	elapsed: 0.55s, reconstruction error: 3.41
# Epoch 14:	#####################################################	elapsed: 0.54s, reconstruction error: 3.32
# Epoch 15:	#####################################################	elapsed: 0.65s, reconstruction error: 3.37
# Epoch 16:	#####################################################	elapsed: 0.93s, reconstruction error: 3.15
# Epoch 17:	#####################################################	elapsed: 1.35s, reconstruction error: 3.16
# Epoch 18:	#####################################################	elapsed: 1.30s, reconstruction error: 3.13
# Epoch 19:	#####################################################	elapsed: 1.44s, reconstruction error: 3.12
# Epoch 20:	#####################################################	elapsed: 1.26s, reconstruction error: 3.14
# Epoch 21:	#####################################################	elapsed: 1.22s, reconstruction error: 3.13
# Epoch 22:	#####################################################	elapsed: 1.22s, reconstruction error: 2.94
# Epoch 23:	#####################################################	elapsed: 0.79s, reconstruction error: 3.12
# Epoch 24:	#####################################################	elapsed: 0.59s, reconstruction error: 3.11
# Epoch 25:	#####################################################	elapsed: 0.68s, reconstruction error: 3.07
# Epoch 26:	#####################################################	elapsed: 0.66s, reconstruction error: 3.04
# Epoch 27:	#####################################################	elapsed: 0.58s, reconstruction error: 3.07
# Epoch 28:	#####################################################	elapsed: 0.55s, reconstruction error: 3.09
# Epoch 29:	#####################################################	elapsed: 0.65s, reconstruction error: 3.12
# Epoch 30:	#####################################################	elapsed: 0.56s, reconstruction error: 3.04
# Epoch 31:	#####################################################	elapsed: 0.65s, reconstruction error: 2.91
# Epoch 32:	#####################################################	elapsed: 0.63s, reconstruction error: 3.03
# Epoch 33:	#####################################################	elapsed: 0.62s, reconstruction error: 2.95
# Epoch 34:	#####################################################	elapsed: 0.66s, reconstruction error: 3.00
# Epoch 35:	#####################################################	elapsed: 0.71s, reconstruction error: 3.00
# Epoch 36:	#####################################################	elapsed: 0.53s, reconstruction error: 2.93
# Epoch 37:	#####################################################	elapsed: 0.64s, reconstruction error: 2.89
# Epoch 38:	#####################################################	elapsed: 0.75s, reconstruction error: 2.97
# Epoch 39:	#####################################################	elapsed: 0.67s, reconstruction error: 2.90
# Epoch 40:	#####################################################	elapsed: 0.64s, reconstruction error: 2.79
# Epoch 41:	#####################################################	elapsed: 0.58s, reconstruction error: 2.91
# Epoch 42:	#####################################################	elapsed: 0.64s, reconstruction error: 2.87
# Epoch 43:	#####################################################	elapsed: 0.66s, reconstruction error: 2.98
# Epoch 44:	#####################################################	elapsed: 0.54s, reconstruction error: 2.90
# Epoch 45:	#####################################################	elapsed: 0.49s, reconstruction error: 2.91
# Epoch 46:	#####################################################	elapsed: 0.69s, reconstruction error: 2.86
# Epoch 47:	#####################################################	elapsed: 0.66s, reconstruction error: 2.83
# Epoch 48:	#####################################################	elapsed: 0.65s, reconstruction error: 2.87
# Epoch 49:	#####################################################	elapsed: 0.50s, reconstruction error: 2.86
# Training finished!

# %%
draw_layer_samples(dbn, 0, monitoring_set[:8*16])

# %%
draw_layer_samples(dbn, 1, monitoring_set[:8*16])

# %%
draw_layer_samples(dbn, 2, monitoring_set[:8*16])
