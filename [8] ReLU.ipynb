# %%
import numpy as np
import matplotlib.pyplot as plt
import time
# import mkl

# mkl.set_num_threads(2)
np.random.seed(1234)

# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'
plt.rcParams["figure.figsize"] = [16, 9]

# %% [markdown]
# ### Handy utility functions

# %%
def append_ones(matrix, axis=1):
    return np.concatenate((matrix, np.ones((matrix.shape[0], 1), dtype=np.float32)), axis=axis)

def zeros(*dims):
    return np.zeros(shape=tuple(dims), dtype=np.float32)

def ones(*dims):
    return np.ones(shape=tuple(dims), dtype=np.float32)

def rand(*dims):
    return np.random.rand(*dims).astype(np.float32)

def randn(*dims):
    return np.random.randn(*dims).astype(np.float32)

def chunks(seq, size):
    return (seq[pos:pos + size] for pos in range(0, len(seq), size))

def as_matrix(vector):
    return np.reshape(vector, (-1, 1))

def one_hot_encode(labels):
    one_hot = zeros(labels.shape[0], np.max(labels) + 1) 
    one_hot[np.arange(labels.shape[0]), labels] = 1
    return one_hot.astype(np.float32)

def classify(mlp, batch):
    probabilities = forward_pass(mlp, batch, False)
    return np.argmax(probabilities, axis=1)

def tiles(examples):
    rows_count = examples.shape[0]
    cols_count = examples.shape[1]
    tile_height = examples.shape[2]
    tile_width = examples.shape[3]
    
    space_between_tiles = 2
    img_matrix = np.empty(shape=(rows_count * (tile_height + space_between_tiles) - space_between_tiles,  
                                 cols_count * (tile_width + space_between_tiles) - space_between_tiles))
    img_matrix.fill(np.nan)

    for r in range(rows_count):
        for c in range(cols_count):
            x_0 = r * (tile_height + space_between_tiles)
            y_0 = c * (tile_width + space_between_tiles)
            ex_min = np.min(examples[r, c])
            ex_max = np.max(examples[r, c])
            img_matrix[x_0:x_0 + tile_height, y_0:y_0 + tile_width] = (examples[r, c] - ex_min) / (ex_max - ex_min)
    
    plt.matshow(img_matrix, cmap='gray', interpolation='none')
    plt.axis('off')
    plt.show()

def draw_rbm_filters(rbm):
    filters = np.reshape(np.transpose(rbm.W)[:-1, :-1], newshape=(8, -1, 28, 28))
    tiles(filters)

def draw_layer_filters(layer):
    filters = np.reshape(layer.W[:-1].T, newshape=(8, -1, 28, 28))
    tiles(filters)

# %% [markdown]
# ### Activation functions

# %%
def sigmoid(batch, stochastic=False):
    activations = 1.0 / (1.0 + np.exp(-batch))
    if stochastic:
        return activations > rand(*activations.shape).astype(np.float32)
    else:
        return activations

def sigmoid_derivative(batch):
    s = sigmoid(batch)
    return s * (1.0 - s)

def softmax(batch):
    numerator = np.exp(batch - np.max(batch, axis=1, keepdims=True))
    denominator = np.sum(numerator, axis=1, keepdims=True)
    return numerator / denominator

# %% [markdown]
# # MNIST dataset

# %%
import mnist
digits = np.reshape(mnist.train_images()[:12*24], newshape=(12, 24, 28, 28))
tiles(digits)

# %% [markdown]
# # ReLU and Max-Norm regularization

# %%
def relu(batch, stochastic=False):
    noise = np.random.normal(scale=np.std(batch), size=batch.shape) if stochastic else 0
    
    return np.maximum(0, batch + noise)
    
def relu_derivative(batch):
    return np.where(batch <= 0, 0, 1)

# %%
def limit_weights(weights, limit):
    col_norms = np.linalg.norm(weights, axis=0)
    scale_factors = np.where(col_norms > limit, limit / col_norms, 1)

    return weights * scale_factors

# %% [markdown]
# # RBM & DBN training

# %%
class Rbm:
    def __init__(self, visible_size, hidden_size, visible_act_func, hidden_act_func, 
                 learning_rate, momentum, weight_limit):
        self.visible_size = visible_size
        self.hidden_size = hidden_size
        
        self.visible_act_func = visible_act_func
        self.hidden_act_func = hidden_act_func
        
        self.learning_rate = learning_rate
        self.momentum = momentum
        
        self.weight_limit = weight_limit
        
        self.reset()
    
    def reset(self):
        self.W = np.random.normal(scale=0.01, size=(self.visible_size+1, self.hidden_size+1)).astype(np.float32)
        self.W[:, -1] = 0.0
        self.W[-1, :] = 0.0
        self.M = zeros(self.visible_size+1, self.hidden_size+1)

# %%
def cdk(rbm, minibatch, k=1):
    observations_count = minibatch.shape[0]

    positive_visible = minibatch
    negative_visible = append_ones(zeros(observations_count, rbm.visible_size))

    positive_hidden = append_ones(zeros(observations_count, rbm.hidden_size))
    negative_hidden = append_ones(zeros(observations_count, rbm.hidden_size))

    z = minibatch @ rbm.W[:, :-1]
    positive_hidden[:, :-1] = rbm.hidden_act_func(z)
    negative_hidden[:, :-1] = rbm.hidden_act_func(z, stochastic=True)

    for cd_i in range(k):
        negative_visible[:, :-1] = rbm.visible_act_func(negative_hidden @ rbm.W[:-1, :].T,
                                                        stochastic=True)
        z = negative_visible @ rbm.W[:, :-1]
        if cd_i < (k - 1):
            negative_hidden[:, :-1] = rbm.hidden_act_func(z, stochastic=True)
        else:
            negative_hidden[:, :-1] = rbm.hidden_act_func(z)

    rbm.M *= rbm.momentum
    rbm.M += (rbm.learning_rate / observations_count) * positive_visible.T @ positive_hidden
    rbm.M -= (rbm.learning_rate / observations_count) * negative_visible.T @ negative_hidden

    rbm.W += rbm.M
    
    if rbm.weight_limit > 0.0:
        rbm.W[:-1, :-1] = limit_weights(rbm.W[:-1, :-1], rbm.weight_limit)

def reconstruction_error(rbm, minibatch):
    observations_count = minibatch.shape[0]

    hidden = append_ones(zeros(observations_count, rbm.hidden_size))
    
    hidden[:, :-1] =  rbm.hidden_act_func(minibatch @ rbm.W[:, :-1], stochastic=True)
    visible = rbm.visible_act_func(hidden @ np.transpose(rbm.W[:-1, :]))
    
    error = minibatch[:, :-1] - visible
    error = np.sum(np.square(error)) / observations_count
    
    return error

# %%
def propagate_up(dbn, layers_count, visible):
    for i in range(layers_count):
        visible = append_ones(dbn[i].hidden_act_func(visible @ dbn[i].W[:, :-1]))
    return visible

def propagate_down(dbn, layers_count, hidden):
    for i in reversed(range(layers_count)):
        hidden = append_ones(dbn[i].visible_act_func(hidden @ np.transpose(dbn[i].W[:-1, :])))
    return hidden

def dbn_reconstruction_error(dbn, layer_idx, minibatch):
    propagated = propagate_up(dbn, layer_idx, minibatch)
    return reconstruction_error(dbn[layer_idx], propagated)

def train_dbn_layer(dbn, layer_idx, dataset, batch_size):
    dataset = propagate_up(dbn, layer_idx, dataset)
    
    batches_limit = dataset.shape[0] / batch_size
    for batch_idx, batch in enumerate(chunks(dataset, batch_size)):
        cdk(dbn[layer_idx], batch)
        if batch_idx % round(batches_limit / 40) == 0: print("#", end="")
            
def run_dbn_training(dbn, dataset, monitoring_set, batch_size, epochs_count, target_momentum=0.9):
    for layer_idx in range(len(dbn)):
        print("\nLearning layer {}".format(layer_idx+1))

        for epoch in range(epochs_count):
            print("Epoch {}:".format(epoch+1),  end="\t")

            if epoch == 5:
                dbn[layer_idx].momentum = target_momentum

            start_time = time.time()
            train_dbn_layer(dbn, layer_idx, dataset, batch_size)
            elapsed = time.time() - start_time

            error = dbn_reconstruction_error(dbn, layer_idx, monitoring_set)
            print("\telapsed: {0:>2.2f}s, reconstruction error: {1:>2.2f}".format(elapsed, error))

# %% [markdown]
# # MLP training

# %%
class Layer:
    def __init__(self, visible_size, hidden_size, activation_fun, d_activation_fun, 
                 learning_rate, momentum, weight_limit):
        self.visible_size = visible_size
        self.hidden_size = hidden_size
        
        self.activation_fun = activation_fun
        self.d_activation_fun = d_activation_fun
                
        self.learning_rate = learning_rate
        self.momentum = momentum
        
        self.weight_limit = weight_limit
        
        self.reset()
    
    def reset(self):
        self.W = np.random.normal(scale=0.01, size=(self.visible_size+1, self.hidden_size)).astype(np.float32)
        self.W[-1, :] = 0.0
        
        self.activations = None
        self.d_activations = None
        self.deltas = None

        self.M = zeros(self.visible_size+1, self.hidden_size)

# %% [markdown]
# ### Forward pass

# %%
def forward_pass(mlp, batch, compute_derivatives):
    visible = batch
    
    for layer_idx, layer in enumerate(mlp):
        z = visible @ layer.W
        activation = layer.activation_fun(z)
        layer.activations = append_ones(activation)
        
        if compute_derivatives and (layer_idx < len(mlp) - 1):
            layer.d_activations = layer.d_activation_fun(z)
        
        visible = layer.activations
        
    return visible[:, :-1]

# %% [markdown]
# ### Error backpropagation

# %%
def error_backpropagate(mlp, batch):
    observations_count = batch.shape[0]
    
    for layer_idx, layer in reversed(list(enumerate(mlp))):
        if layer_idx > 0:
            prev_layer = mlp[layer_idx - 1]
            visible = prev_layer.activations

            prev_layer.deltas = (layer.deltas @ layer.W[:-1].T) * prev_layer.d_activations
        else:
            visible = batch
        
        gradient = (visible.T @ layer.deltas) / observations_count
        layer.M = layer.momentum * layer.M - layer.learning_rate * gradient
        layer.W += layer.M
        
        if layer.weight_limit > 0.0:
            layer.W[:-1, :] = limit_weights(layer.W[:-1, :], layer.weight_limit)

# %% [markdown]
# ### Training procedure

# %%
def train_mlp(mlp, dataset, labels, batch_size):
    batches_limit = dataset.shape[0] / batch_size
    
    batched_data = chunks(dataset, batch_size)
    batched_labels = chunks(labels, batch_size)
    
    for batch_idx, (batch, batch_labels) in enumerate(zip(batched_data, batched_labels)):
        # Forward pass: compute activations and derivatives of activations
        y = forward_pass(mlp, batch, True)
        
        mlp[-1].deltas = y - batch_labels
        
        # Once softmax deltas are set, we may backpropagate errors
        error_backpropagate(mlp, batch)
        
        if batch_idx % round(batches_limit / 40) == 0: print("#", end="")

# %%
def run_mlp_training(mlp, train_set, train_labels, validation_set, validation_labels,
                     batch_size, epochs_count, target_momentum=0.95):
    for epoch in range(epochs_count):
        print("Epoch {}:".format(epoch+1),  end="\t")
        
        if epoch == 5:
            for layer in mlp: layer.momentum = target_momentum
        
        start_time = time.time()
        train_mlp(mlp, train_set, train_labels, batch_size)
        elapsed = time.time() - start_time

        predictions = classify(mlp, validation_set)
        accuracy = 100.0 * np.sum(predictions == validation_labels) / predictions.shape[0]
        print("\telapsed: {0:>2.2f}s, accuracy: {1:>2.2f}".format(elapsed, accuracy))

    print("Training finished!")

# %% [markdown]
# #  Initializing MLP with DBN weights
#
# Implement initialization of MLP weights (and biases) using weights (and biases) from the DBN layers.
#
# Make sure that the MLP weights (and biases) are **copies** of the DBN weights (and biases). You can use ```np.copy(...)``` function to copy the weights (simple assignment will make a view instead of a copy).

# %%
def initialize_mlp(mlp, dbn):
    for mlp_layer, dbn_layer in zip(mlp, dbn):
        mlp_layer.W = np.copy(dbn_layer.W[:, :-1])

# %% [markdown]
# # MNIST digits classification

# %%
DATASET_SIZE = 10000 # 60000 for whole dataset
DIGIT_SIZE = 28

##### Train set #####

mnist_train_images = mnist.train_images().astype(np.float32) / 255.0
mnist_train_labels = mnist.train_labels()

order = np.random.permutation(len(mnist_train_images))
mnist_train_images = mnist_train_images[order]
mnist_train_labels = mnist_train_labels[order]

mnist_train_images = np.reshape(mnist_train_images[:DATASET_SIZE],
                                newshape=(DATASET_SIZE, DIGIT_SIZE*DIGIT_SIZE))
mnist_train_images = append_ones(mnist_train_images)

mnist_train_labels = mnist_train_labels[:DATASET_SIZE]
mnist_train_labels = one_hot_encode(mnist_train_labels)

monitoring_set_indeces = np.random.choice(mnist_train_images.shape[0], 512, replace=False)
monitoring_set = mnist_train_images[monitoring_set_indeces]

##### Test set #####

mnist_test_images = mnist.test_images().astype(np.float32) / 255.0
mnist_test_images = np.reshape(mnist_test_images, newshape=(-1, DIGIT_SIZE*DIGIT_SIZE))
mnist_test_images = append_ones(mnist_test_images)

mnist_test_labels = mnist.test_labels()

# %%
VISIBLE_LAYER_SIZE = DIGIT_SIZE*DIGIT_SIZE
HIDDEN_LAYER_SIZE = 256

BATCH_SIZE = 128
EPOCHS_COUNT = 50

MLP_LEARNING_RATE = 0.03
SOFTMAX_LEARNING_RATE = 0.15
RBM_LEARNING_RATE = 0.003
MOMENTUM = 0.5

# %% [markdown]
# ### Plain vs pretrained comparison

# %%
from IPython.core.display import HTML

def compare_pretraining_results(mlp, dbn,
                                train_set, train_labels,
                                validation_set, validation_labels,
                                monitoring_set,
                                batch_size, epochs_count):
    for layer in mlp:
        layer.reset()

    display(HTML('<h3>Plain MLP training</h3>'))
    run_mlp_training(mlp,
                     train_set, train_labels,
                     validation_set, validation_labels,
                     batch_size, epochs_count)
    
    display(HTML('<h3>Input layer filters in the plain MLP</h3>'))
    draw_layer_filters(mlp[0])
    
    display(HTML('<h3>Largest norms of weight-vectors in the plain MLP layers</h3>'))
    for i, layer in enumerate(mlp):
        max_norm = np.max(np.linalg.norm(layer.W[:-1, :], axis=0))
        print('\tlayer {0}: {1:.2f}'.format(i+1, max_norm))
    
    display(HTML('<h3>DBN training</h3>'))
    run_dbn_training(dbn, train_set, monitoring_set, batch_size, epochs_count)
    
    for layer in mlp:
        layer.reset()
    
    initialize_mlp(mlp, dbn)
    
    display(HTML('<h3>Finetuning pretrained MLP</h3>'))
    run_mlp_training(mlp,
                     train_set, train_labels,
                     validation_set, validation_labels,
                     batch_size, epochs_count)
    
    display(HTML('<h3>First layer filters in the DBN</h3>'))
    draw_rbm_filters(dbn[0])
    
    display(HTML('<h3>Input layer filters in the pretrained & finetuned MLP</h3>'))
    draw_layer_filters(mlp[0])

    display(HTML('<h3>Largest norms of weight-vectors in the finetuned MLP layers</h3>'))
    for i, layer in enumerate(mlp):
        max_norm = np.max(np.linalg.norm(layer.W[:-1, :], axis=0))
        print('\tlayer {0}: {1:.2f}'.format(i+1, max_norm))

# %% [markdown]
# ### Shallow ReLU network

# %%
shallow_mlp = [
    Layer(VISIBLE_LAYER_SIZE, HIDDEN_LAYER_SIZE, relu, relu_derivative, MLP_LEARNING_RATE, MOMENTUM,
          weight_limit=2.0),
    Layer(HIDDEN_LAYER_SIZE, HIDDEN_LAYER_SIZE, relu, relu_derivative, MLP_LEARNING_RATE, MOMENTUM,
          weight_limit=1.0),
    Layer(HIDDEN_LAYER_SIZE, 10, softmax, None, SOFTMAX_LEARNING_RATE, MOMENTUM,
          weight_limit=4.0)
]

shallow_dbn = [
    Rbm(VISIBLE_LAYER_SIZE, HIDDEN_LAYER_SIZE, sigmoid, relu, RBM_LEARNING_RATE, MOMENTUM,
        weight_limit=2.0),
    Rbm(HIDDEN_LAYER_SIZE, HIDDEN_LAYER_SIZE, relu, relu, RBM_LEARNING_RATE, MOMENTUM,
        weight_limit=1.0)
]

compare_pretraining_results(shallow_mlp, shallow_dbn,
                            mnist_train_images, mnist_train_labels,
                            mnist_test_images, mnist_test_labels,
                            monitoring_set,
                            BATCH_SIZE, EPOCHS_COUNT)
# Out:
# <h3>Plain MLP training</h3>
# Epoch 1:	########################################	elapsed: 0.57s, accuracy: 11.35
# Epoch 2:	########################################	elapsed: 0.53s, accuracy: 31.54
# Epoch 3:	########################################	elapsed: 0.50s, accuracy: 65.26
# Epoch 4:	########################################	elapsed: 0.47s, accuracy: 74.15
# Epoch 5:	########################################	elapsed: 0.50s, accuracy: 80.37
# Epoch 6:	########################################	elapsed: 0.51s, accuracy: 89.79
# Epoch 7:	########################################	elapsed: 0.50s, accuracy: 92.37
# Epoch 8:	########################################	elapsed: 0.49s, accuracy: 93.13
# Epoch 9:	########################################	elapsed: 0.56s, accuracy: 93.87
# Epoch 10:	########################################	elapsed: 0.52s, accuracy: 94.59
# Epoch 11:	########################################	elapsed: 0.51s, accuracy: 94.20
# Epoch 12:	########################################	elapsed: 0.49s, accuracy: 95.28
# Epoch 13:	########################################	elapsed: 0.55s, accuracy: 94.79
# Epoch 14:	########################################	elapsed: 0.52s, accuracy: 94.56
# Epoch 15:	########################################	elapsed: 0.52s, accuracy: 95.26
# Epoch 16:	########################################	elapsed: 0.54s, accuracy: 94.95
# Epoch 17:	########################################	elapsed: 0.50s, accuracy: 95.56
# Epoch 18:	########################################	elapsed: 0.49s, accuracy: 95.75
# Epoch 19:	########################################	elapsed: 0.53s, accuracy: 95.85
# Epoch 20:	########################################	elapsed: 0.53s, accuracy: 95.85
# Epoch 21:	########################################	elapsed: 0.52s, accuracy: 95.97
# Epoch 22:	########################################	elapsed: 0.54s, accuracy: 95.75
# Epoch 23:	########################################	elapsed: 0.53s, accuracy: 96.21
# Epoch 24:	########################################	elapsed: 0.51s, accuracy: 96.69
# Epoch 25:	########################################	elapsed: 0.50s, accuracy: 96.61
# Epoch 26:	########################################	elapsed: 0.57s, accuracy: 96.61
# Epoch 27:	########################################	elapsed: 0.48s, accuracy: 96.62
# Epoch 28:	########################################	elapsed: 0.50s, accuracy: 96.60
# Epoch 29:	########################################	elapsed: 0.50s, accuracy: 96.60
# Epoch 30:	########################################	elapsed: 0.55s, accuracy: 96.60
# Epoch 31:	########################################	elapsed: 0.51s, accuracy: 96.64
# Epoch 32:	########################################	elapsed: 0.49s, accuracy: 96.64
# Epoch 33:	########################################	elapsed: 0.54s, accuracy: 96.62
# Epoch 34:	########################################	elapsed: 0.52s, accuracy: 96.61
# Epoch 35:	########################################	elapsed: 0.60s, accuracy: 96.61
# Epoch 36:	########################################	elapsed: 0.74s, accuracy: 96.62
# Epoch 37:	########################################	elapsed: 0.57s, accuracy: 96.63
# Epoch 38:	########################################	elapsed: 0.55s, accuracy: 96.63
# Epoch 39:	########################################	elapsed: 0.55s, accuracy: 96.65
# Epoch 40:	########################################	elapsed: 0.59s, accuracy: 96.65
# Epoch 41:	########################################	elapsed: 0.58s, accuracy: 96.64
# Epoch 42:	########################################	elapsed: 0.67s, accuracy: 96.65
# Epoch 43:	########################################	elapsed: 0.70s, accuracy: 96.65
# Epoch 44:	########################################	elapsed: 0.55s, accuracy: 96.65
# Epoch 45:	########################################	elapsed: 0.71s, accuracy: 96.64
# Epoch 46:	########################################	elapsed: 0.65s, accuracy: 96.64
# Epoch 47:	########################################	elapsed: 0.68s, accuracy: 96.63
# Epoch 48:	########################################	elapsed: 0.65s, accuracy: 96.64
# Epoch 49:	########################################	elapsed: 0.74s, accuracy: 96.64
# Epoch 50:	########################################	elapsed: 0.73s, accuracy: 96.64
# Training finished!
# <h3>Input layer filters in the plain MLP</h3>
# <h3>Largest norms of weight-vectors in the plain MLP layers</h3>
# 	layer 1: 1.78
# 	layer 2: 1.00
# 	layer 3: 4.00
# <h3>DBN training</h3>
# Learning layer 1
# Epoch 1:	########################################	elapsed: 0.51s, reconstruction error: 76.37
# Epoch 2:	########################################	elapsed: 0.51s, reconstruction error: 54.65
# Epoch 3:	########################################	elapsed: 0.42s, reconstruction error: 42.34
# Epoch 4:	########################################	elapsed: 0.45s, reconstruction error: 36.07
# Epoch 5:	########################################	elapsed: 0.41s, reconstruction error: 32.43
# Epoch 6:	########################################	elapsed: 0.40s, reconstruction error: 25.94
# Epoch 7:	########################################	elapsed: 0.41s, reconstruction error: 22.99
# Epoch 8:	########################################	elapsed: 0.44s, reconstruction error: 21.65
# Epoch 9:	########################################	elapsed: 0.44s, reconstruction error: 20.52
# Epoch 10:	########################################	elapsed: 0.46s, reconstruction error: 19.95
# Epoch 11:	########################################	elapsed: 0.48s, reconstruction error: 19.77
# Epoch 12:	########################################	elapsed: 0.50s, reconstruction error: 19.31
# Epoch 13:	########################################	elapsed: 0.51s, reconstruction error: 19.13
# Epoch 14:	########################################	elapsed: 0.51s, reconstruction error: 18.79
# Epoch 15:	########################################	elapsed: 0.54s, reconstruction error: 18.82
# Epoch 16:	########################################	elapsed: 0.56s, reconstruction error: 18.68
# Epoch 17:	########################################	elapsed: 0.56s, reconstruction error: 18.89
# Epoch 18:	########################################	elapsed: 0.54s, reconstruction error: 18.43
# Epoch 19:	########################################	elapsed: 0.58s, reconstruction error: 18.75
# Epoch 20:	########################################	elapsed: 0.53s, reconstruction error: 18.51
# Epoch 21:	########################################	elapsed: 0.52s, reconstruction error: 18.47
# Epoch 22:	########################################	elapsed: 0.49s, reconstruction error: 18.45
# Epoch 23:	########################################	elapsed: 0.54s, reconstruction error: 18.07
# Epoch 24:	########################################	elapsed: 0.48s, reconstruction error: 18.12
# Epoch 25:	########################################	elapsed: 0.50s, reconstruction error: 18.47
# Epoch 26:	########################################	elapsed: 0.50s, reconstruction error: 18.30
# Epoch 27:	########################################	elapsed: 0.48s, reconstruction error: 18.04
# Epoch 28:	########################################	elapsed: 0.48s, reconstruction error: 18.09
# Epoch 29:	########################################	elapsed: 0.48s, reconstruction error: 18.35
# Epoch 30:	########################################	elapsed: 0.44s, reconstruction error: 17.84
# Epoch 31:	########################################	elapsed: 0.45s, reconstruction error: 17.92
# Epoch 32:	########################################	elapsed: 0.47s, reconstruction error: 18.16
# Epoch 33:	########################################	elapsed: 0.50s, reconstruction error: 17.97
# Epoch 34:	########################################	elapsed: 0.54s, reconstruction error: 18.31
# Epoch 35:	########################################	elapsed: 0.54s, reconstruction error: 18.00
# Epoch 36:	########################################	elapsed: 0.50s, reconstruction error: 18.34
# Epoch 37:	########################################	elapsed: 0.53s, reconstruction error: 18.07
# Epoch 38:	########################################	elapsed: 0.56s, reconstruction error: 17.89
# Epoch 39:	########################################	elapsed: 0.59s, reconstruction error: 18.13
# Epoch 40:	########################################	elapsed: 0.51s, reconstruction error: 18.06
# Epoch 41:	########################################	elapsed: 0.57s, reconstruction error: 17.91
# Epoch 42:	########################################	elapsed: 0.59s, reconstruction error: 18.32
# Epoch 43:	########################################	elapsed: 0.60s, reconstruction error: 18.27
# Epoch 44:	########################################	elapsed: 0.57s, reconstruction error: 18.23
# Epoch 45:	########################################	elapsed: 0.60s, reconstruction error: 18.38
# Epoch 46:	########################################	elapsed: 0.55s, reconstruction error: 18.36
# Epoch 47:	########################################	elapsed: 0.59s, reconstruction error: 18.08
# Epoch 48:	########################################	elapsed: 0.58s, reconstruction error: 17.92
# Epoch 49:	########################################	elapsed: 0.58s, reconstruction error: 17.95
# Epoch 50:	########################################	elapsed: 0.59s, reconstruction error: 17.86
#
# Learning layer 2
# Epoch 1:	########################################	elapsed: 0.44s, reconstruction error: 132.72
# Epoch 2:	########################################	elapsed: 0.44s, reconstruction error: 132.66
# Epoch 3:	########################################	elapsed: 0.44s, reconstruction error: 144.66
# Epoch 4:	########################################	elapsed: 0.43s, reconstruction error: 154.34
# Epoch 5:	########################################	elapsed: 0.44s, reconstruction error: 157.43
# Epoch 6:	########################################	elapsed: 0.45s, reconstruction error: 203.95
# Epoch 7:	########################################	elapsed: 0.44s, reconstruction error: 209.33
# Epoch 8:	########################################	elapsed: 0.39s, reconstruction error: 215.21
# Epoch 9:	########################################	elapsed: 0.41s, reconstruction error: 219.73
# Epoch 10:	########################################	elapsed: 0.38s, reconstruction error: 238.25
# Epoch 11:	########################################	elapsed: 0.42s, reconstruction error: 225.43
# Epoch 12:	########################################	elapsed: 0.41s, reconstruction error: 242.19
# Epoch 13:	########################################	elapsed: 0.42s, reconstruction error: 234.81
# Epoch 14:	########################################	elapsed: 0.41s, reconstruction error: 236.92
# Epoch 15:	########################################	elapsed: 0.42s, reconstruction error: 230.54
# Epoch 16:	########################################	elapsed: 0.43s, reconstruction error: 244.00
# Epoch 17:	########################################	elapsed: 0.40s, reconstruction error: 248.40
# Epoch 18:	########################################	elapsed: 0.42s, reconstruction error: 242.60
# Epoch 19:	########################################	elapsed: 0.41s, reconstruction error: 244.92
# Epoch 20:	########################################	elapsed: 0.41s, reconstruction error: 235.09
# Epoch 21:	########################################	elapsed: 0.41s, reconstruction error: 262.62
# Epoch 22:	########################################	elapsed: 0.35s, reconstruction error: 238.68
# Epoch 23:	########################################	elapsed: 0.36s, reconstruction error: 233.57
# Epoch 24:	########################################	elapsed: 0.35s, reconstruction error: 249.80
# Epoch 25:	########################################	elapsed: 0.30s, reconstruction error: 248.26
# Epoch 26:	########################################	elapsed: 0.28s, reconstruction error: 249.37
# Epoch 27:	########################################	elapsed: 0.30s, reconstruction error: 239.35
# Epoch 28:	########################################	elapsed: 0.30s, reconstruction error: 242.18
# Epoch 29:	########################################	elapsed: 0.29s, reconstruction error: 241.23
# Epoch 30:	########################################	elapsed: 0.32s, reconstruction error: 253.75
# Epoch 31:	########################################	elapsed: 0.29s, reconstruction error: 245.80
# Epoch 32:	########################################	elapsed: 0.33s, reconstruction error: 245.73
# Epoch 33:	########################################	elapsed: 0.29s, reconstruction error: 236.28
# Epoch 34:	########################################	elapsed: 0.36s, reconstruction error: 242.77
# Epoch 35:	########################################	elapsed: 0.33s, reconstruction error: 241.37
# Epoch 36:	########################################	elapsed: 0.33s, reconstruction error: 249.73
# Epoch 37:	########################################	elapsed: 0.36s, reconstruction error: 248.52
# Epoch 38:	########################################	elapsed: 0.36s, reconstruction error: 252.51
# Epoch 39:	########################################	elapsed: 0.35s, reconstruction error: 241.00
# Epoch 40:	########################################	elapsed: 0.36s, reconstruction error: 246.08
# Epoch 41:	########################################	elapsed: 0.35s, reconstruction error: 242.31
# Epoch 42:	########################################	elapsed: 0.31s, reconstruction error: 252.21
# Epoch 43:	########################################	elapsed: 0.30s, reconstruction error: 254.21
# Epoch 44:	########################################	elapsed: 0.32s, reconstruction error: 240.95
# Epoch 45:	########################################	elapsed: 0.32s, reconstruction error: 237.12
# Epoch 46:	########################################	elapsed: 0.29s, reconstruction error: 239.07
# Epoch 47:	########################################	elapsed: 0.37s, reconstruction error: 247.61
# Epoch 48:	########################################	elapsed: 0.32s, reconstruction error: 236.89
# Epoch 49:	########################################	elapsed: 0.35s, reconstruction error: 244.98
# Epoch 50:	########################################	elapsed: 0.30s, reconstruction error: 246.15
# <h3>Finetuning pretrained MLP</h3>
# Epoch 1:	########################################	elapsed: 0.53s, accuracy: 94.32
# Epoch 2:	########################################	elapsed: 0.53s, accuracy: 94.77
# Epoch 3:	########################################	elapsed: 0.57s, accuracy: 95.99
# Epoch 4:	########################################	elapsed: 0.55s, accuracy: 96.06
# Epoch 5:	########################################	elapsed: 0.55s, accuracy: 96.67
# Epoch 6:	########################################	elapsed: 0.55s, accuracy: 96.66
# Epoch 7:	########################################	elapsed: 0.55s, accuracy: 96.52
# Epoch 8:	########################################	elapsed: 0.51s, accuracy: 96.48
# Epoch 9:	########################################	elapsed: 0.51s, accuracy: 96.63
# Epoch 10:	########################################	elapsed: 0.51s, accuracy: 96.84
# Epoch 11:	########################################	elapsed: 0.57s, accuracy: 96.85
# Epoch 12:	########################################	elapsed: 0.60s, accuracy: 97.17
# Epoch 13:	########################################	elapsed: 0.58s, accuracy: 97.22
# Epoch 14:	########################################	elapsed: 0.58s, accuracy: 97.19
# Epoch 15:	########################################	elapsed: 0.66s, accuracy: 97.17
# Epoch 16:	########################################	elapsed: 0.71s, accuracy: 97.22
# Epoch 17:	########################################	elapsed: 0.72s, accuracy: 97.18
# Epoch 18:	########################################	elapsed: 0.72s, accuracy: 97.18
# Epoch 19:	########################################	elapsed: 0.64s, accuracy: 97.17
# Epoch 20:	########################################	elapsed: 0.58s, accuracy: 97.19
# Epoch 21:	########################################	elapsed: 0.64s, accuracy: 97.18
# Epoch 22:	########################################	elapsed: 0.57s, accuracy: 97.19
# Epoch 23:	########################################	elapsed: 0.60s, accuracy: 97.20
# Epoch 24:	########################################	elapsed: 0.58s, accuracy: 97.19
# Epoch 25:	########################################	elapsed: 0.56s, accuracy: 97.19
# Epoch 26:	########################################	elapsed: 0.59s, accuracy: 97.19
# Epoch 27:	########################################	elapsed: 0.71s, accuracy: 97.21
# Epoch 28:	########################################	elapsed: 0.74s, accuracy: 97.20
# Epoch 29:	########################################	elapsed: 0.77s, accuracy: 97.19
# Epoch 30:	########################################	elapsed: 0.67s, accuracy: 97.19
# Epoch 31:	########################################	elapsed: 0.54s, accuracy: 97.20
# Epoch 32:	########################################	elapsed: 0.58s, accuracy: 97.21
# Epoch 33:	########################################	elapsed: 0.60s, accuracy: 97.21
# Epoch 34:	########################################	elapsed: 0.52s, accuracy: 97.20
# Epoch 35:	########################################	elapsed: 0.56s, accuracy: 97.19
# Epoch 36:	########################################	elapsed: 0.51s, accuracy: 97.19
# Epoch 37:	########################################	elapsed: 0.49s, accuracy: 97.18
# Epoch 38:	########################################	elapsed: 0.50s, accuracy: 97.18
# Epoch 39:	########################################	elapsed: 0.51s, accuracy: 97.19
# Epoch 40:	########################################	elapsed: 0.53s, accuracy: 97.18
# Epoch 41:	########################################	elapsed: 0.53s, accuracy: 97.18
# Epoch 42:	########################################	elapsed: 0.55s, accuracy: 97.15
# Epoch 43:	########################################	elapsed: 0.50s, accuracy: 97.15
# Epoch 44:	########################################	elapsed: 0.52s, accuracy: 97.16
# Epoch 45:	########################################	elapsed: 0.52s, accuracy: 97.17
# Epoch 46:	########################################	elapsed: 0.54s, accuracy: 97.17
# Epoch 47:	########################################	elapsed: 0.55s, accuracy: 97.17
# Epoch 48:	########################################	elapsed: 0.57s, accuracy: 97.17
# Epoch 49:	########################################	elapsed: 0.56s, accuracy: 97.17
# Epoch 50:	########################################	elapsed: 0.53s, accuracy: 97.18
# Training finished!
# <h3>First layer filters in the DBN</h3>
# <h3>Input layer filters in the pretrained & finetuned MLP</h3>
# <h3>Largest norms of weight-vectors in the finetuned MLP layers</h3>
# 	layer 1: 2.00
# 	layer 2: 1.00
# 	layer 3: 4.00

# %% [markdown]
# ### Deep ReLU network

# %%
deep_mlp = [
    Layer(VISIBLE_LAYER_SIZE, HIDDEN_LAYER_SIZE, relu, relu_derivative, MLP_LEARNING_RATE, MOMENTUM,
          weight_limit=2.0),
    Layer(HIDDEN_LAYER_SIZE, HIDDEN_LAYER_SIZE, relu, relu_derivative, MLP_LEARNING_RATE, MOMENTUM,
          weight_limit=1.0),
    Layer(HIDDEN_LAYER_SIZE, 2 * HIDDEN_LAYER_SIZE, relu, relu_derivative, MLP_LEARNING_RATE, MOMENTUM,
          weight_limit=1.0),
    Layer(2 * HIDDEN_LAYER_SIZE, 10, softmax, None, SOFTMAX_LEARNING_RATE, MOMENTUM,
          weight_limit=4.0)
]

deep_dbn = [
    Rbm(VISIBLE_LAYER_SIZE, HIDDEN_LAYER_SIZE, sigmoid, relu, RBM_LEARNING_RATE, MOMENTUM,
        weight_limit=2.0),
    Rbm(HIDDEN_LAYER_SIZE, HIDDEN_LAYER_SIZE, relu, relu, RBM_LEARNING_RATE, MOMENTUM,
        weight_limit=1.0),
    Rbm(HIDDEN_LAYER_SIZE, 2 * HIDDEN_LAYER_SIZE, relu, relu, RBM_LEARNING_RATE, MOMENTUM,
        weight_limit=1.0)
]

compare_pretraining_results(deep_mlp, deep_dbn,
                            mnist_train_images, mnist_train_labels,
                            mnist_test_images, mnist_test_labels,
                            monitoring_set,
                            BATCH_SIZE, EPOCHS_COUNT)
# Out:
# <h3>Plain MLP training</h3>
# Epoch 1:	########################################	elapsed: 0.88s, accuracy: 11.35
# Epoch 2:	########################################	elapsed: 0.85s, accuracy: 11.35
# Epoch 3:	########################################	elapsed: 0.81s, accuracy: 11.35
# Epoch 4:	########################################	elapsed: 0.79s, accuracy: 11.35
# Epoch 5:	########################################	elapsed: 0.83s, accuracy: 11.35
# Epoch 6:	########################################	elapsed: 0.90s, accuracy: 38.87
# Epoch 7:	########################################	elapsed: 0.86s, accuracy: 79.44
# Epoch 8:	########################################	elapsed: 0.87s, accuracy: 88.57
# Epoch 9:	########################################	elapsed: 0.83s, accuracy: 91.80
# Epoch 10:	########################################	elapsed: 0.77s, accuracy: 93.22
# Epoch 11:	########################################	elapsed: 0.79s, accuracy: 93.46
# Epoch 12:	########################################	elapsed: 0.85s, accuracy: 93.08
# Epoch 13:	########################################	elapsed: 0.83s, accuracy: 91.94
# Epoch 14:	########################################	elapsed: 0.80s, accuracy: 94.15
# Epoch 15:	########################################	elapsed: 0.89s, accuracy: 94.69
# Epoch 16:	########################################	elapsed: 0.95s, accuracy: 94.83
# Epoch 17:	########################################	elapsed: 0.84s, accuracy: 93.80
# Epoch 18:	########################################	elapsed: 0.88s, accuracy: 95.64
# Epoch 19:	########################################	elapsed: 0.82s, accuracy: 95.71
# Epoch 20:	########################################	elapsed: 0.85s, accuracy: 95.38
# Epoch 21:	########################################	elapsed: 0.83s, accuracy: 95.56
# Epoch 22:	########################################	elapsed: 0.82s, accuracy: 95.53
# Epoch 23:	########################################	elapsed: 0.80s, accuracy: 96.15
# Epoch 24:	########################################	elapsed: 0.81s, accuracy: 96.44
# Epoch 25:	########################################	elapsed: 0.83s, accuracy: 96.29
# Epoch 26:	########################################	elapsed: 0.82s, accuracy: 96.05
# Epoch 27:	########################################	elapsed: 0.87s, accuracy: 96.15
# Epoch 28:	########################################	elapsed: 0.82s, accuracy: 96.40
# Epoch 29:	########################################	elapsed: 0.87s, accuracy: 96.70
# Epoch 30:	########################################	elapsed: 0.79s, accuracy: 96.81
# Epoch 31:	########################################	elapsed: 0.83s, accuracy: 96.82
# Epoch 32:	########################################	elapsed: 0.82s, accuracy: 96.87
# Epoch 33:	########################################	elapsed: 0.81s, accuracy: 96.87
# Epoch 34:	########################################	elapsed: 0.82s, accuracy: 96.91
# Epoch 35:	########################################	elapsed: 0.77s, accuracy: 96.90
# Epoch 36:	########################################	elapsed: 0.86s, accuracy: 96.86
# Epoch 37:	########################################	elapsed: 0.78s, accuracy: 96.86
# Epoch 38:	########################################	elapsed: 0.87s, accuracy: 96.87
# Epoch 39:	########################################	elapsed: 0.79s, accuracy: 96.85
# Epoch 40:	########################################	elapsed: 0.79s, accuracy: 96.87
# Epoch 41:	########################################	elapsed: 0.83s, accuracy: 96.85
# Epoch 42:	########################################	elapsed: 0.76s, accuracy: 96.84
# Epoch 43:	########################################	elapsed: 0.79s, accuracy: 96.84
# Epoch 44:	########################################	elapsed: 0.80s, accuracy: 96.84
# Epoch 45:	########################################	elapsed: 0.77s, accuracy: 96.84
# Epoch 46:	########################################	elapsed: 0.86s, accuracy: 96.84
# Epoch 47:	########################################	elapsed: 0.79s, accuracy: 96.84
# Epoch 48:	########################################	elapsed: 0.88s, accuracy: 96.84
# Epoch 49:	########################################	elapsed: 0.83s, accuracy: 96.84
# Epoch 50:	########################################	elapsed: 0.90s, accuracy: 96.83
# Training finished!
# <h3>Input layer filters in the plain MLP</h3>
# <h3>Largest norms of weight-vectors in the plain MLP layers</h3>
# 	layer 1: 2.00
# 	layer 2: 1.00
# 	layer 3: 0.82
# 	layer 4: 4.00
# <h3>DBN training</h3>
# Learning layer 1
# Epoch 1:	########################################	elapsed: 0.43s, reconstruction error: 76.10
# Epoch 2:	########################################	elapsed: 0.41s, reconstruction error: 54.56
# Epoch 3:	########################################	elapsed: 0.40s, reconstruction error: 41.99
# Epoch 4:	########################################	elapsed: 0.37s, reconstruction error: 35.77
# Epoch 5:	########################################	elapsed: 0.37s, reconstruction error: 32.21
# Epoch 6:	########################################	elapsed: 0.37s, reconstruction error: 25.57
# Epoch 7:	########################################	elapsed: 0.38s, reconstruction error: 22.96
# Epoch 8:	########################################	elapsed: 0.39s, reconstruction error: 21.44
# Epoch 9:	########################################	elapsed: 0.43s, reconstruction error: 20.53
# Epoch 10:	########################################	elapsed: 0.37s, reconstruction error: 19.92
# Epoch 11:	########################################	elapsed: 0.38s, reconstruction error: 19.96
# Epoch 12:	########################################	elapsed: 0.36s, reconstruction error: 19.08
# Epoch 13:	########################################	elapsed: 0.38s, reconstruction error: 19.03
# Epoch 14:	########################################	elapsed: 0.39s, reconstruction error: 18.89
# Epoch 15:	########################################	elapsed: 0.41s, reconstruction error: 18.44
# Epoch 16:	########################################	elapsed: 0.42s, reconstruction error: 18.33
# Epoch 17:	########################################	elapsed: 0.44s, reconstruction error: 18.28
# Epoch 18:	########################################	elapsed: 0.49s, reconstruction error: 18.00
# Epoch 19:	########################################	elapsed: 0.48s, reconstruction error: 17.89
# Epoch 20:	########################################	elapsed: 0.48s, reconstruction error: 17.83
# Epoch 21:	########################################	elapsed: 0.48s, reconstruction error: 17.90
# Epoch 22:	########################################	elapsed: 0.52s, reconstruction error: 18.09
# Epoch 23:	########################################	elapsed: 0.51s, reconstruction error: 17.75
# Epoch 24:	########################################	elapsed: 0.49s, reconstruction error: 17.79
# Epoch 25:	########################################	elapsed: 0.51s, reconstruction error: 17.96
# Epoch 26:	########################################	elapsed: 0.55s, reconstruction error: 17.49
# Epoch 27:	########################################	elapsed: 0.50s, reconstruction error: 17.90
# Epoch 28:	########################################	elapsed: 0.51s, reconstruction error: 17.72
# Epoch 29:	########################################	elapsed: 0.52s, reconstruction error: 17.90
# Epoch 30:	########################################	elapsed: 0.55s, reconstruction error: 17.38
# Epoch 31:	########################################	elapsed: 0.49s, reconstruction error: 17.52
# Epoch 32:	########################################	elapsed: 0.41s, reconstruction error: 17.64
# Epoch 33:	########################################	elapsed: 0.41s, reconstruction error: 17.75
# Epoch 34:	########################################	elapsed: 0.48s, reconstruction error: 17.44
# Epoch 35:	########################################	elapsed: 0.48s, reconstruction error: 17.74
# Epoch 36:	########################################	elapsed: 0.47s, reconstruction error: 17.42
# Epoch 37:	########################################	elapsed: 0.47s, reconstruction error: 17.59
# Epoch 38:	########################################	elapsed: 0.47s, reconstruction error: 17.62
# Epoch 39:	########################################	elapsed: 0.51s, reconstruction error: 17.16
# Epoch 40:	########################################	elapsed: 0.50s, reconstruction error: 17.38
# Epoch 41:	########################################	elapsed: 0.51s, reconstruction error: 17.41
# Epoch 42:	########################################	elapsed: 0.57s, reconstruction error: 17.58
# Epoch 43:	########################################	elapsed: 0.53s, reconstruction error: 17.65
# Epoch 44:	########################################	elapsed: 0.52s, reconstruction error: 17.57
# Epoch 45:	########################################	elapsed: 0.52s, reconstruction error: 17.50
# Epoch 46:	########################################	elapsed: 0.56s, reconstruction error: 17.21
# Epoch 47:	########################################	elapsed: 0.52s, reconstruction error: 17.57
# Epoch 48:	########################################	elapsed: 0.46s, reconstruction error: 17.56
# Epoch 49:	########################################	elapsed: 0.47s, reconstruction error: 17.66
# Epoch 50:	########################################	elapsed: 0.52s, reconstruction error: 17.37
#
# Learning layer 2
# Epoch 1:	########################################	elapsed: 0.31s, reconstruction error: 129.74
# Epoch 2:	########################################	elapsed: 0.31s, reconstruction error: 132.23
# Epoch 3:	########################################	elapsed: 0.32s, reconstruction error: 145.06
# Epoch 4:	########################################	elapsed: 0.32s, reconstruction error: 160.15
# Epoch 5:	########################################	elapsed: 0.31s, reconstruction error: 165.62
# Epoch 6:	########################################	elapsed: 0.35s, reconstruction error: 214.27
# Epoch 7:	########################################	elapsed: 0.33s, reconstruction error: 220.08
# Epoch 8:	########################################	elapsed: 0.31s, reconstruction error: 205.55
# Epoch 9:	########################################	elapsed: 0.31s, reconstruction error: 241.56
# Epoch 10:	########################################	elapsed: 0.33s, reconstruction error: 227.95
# Epoch 11:	########################################	elapsed: 0.31s, reconstruction error: 232.70
# Epoch 12:	########################################	elapsed: 0.22s, reconstruction error: 222.57
# Epoch 13:	########################################	elapsed: 0.29s, reconstruction error: 243.52
# Epoch 14:	########################################	elapsed: 0.32s, reconstruction error: 249.23
# Epoch 15:	########################################	elapsed: 0.30s, reconstruction error: 244.28
# Epoch 16:	########################################	elapsed: 0.35s, reconstruction error: 244.93
# Epoch 17:	########################################	elapsed: 0.33s, reconstruction error: 255.53
# Epoch 18:	########################################	elapsed: 0.30s, reconstruction error: 244.88
# Epoch 19:	########################################	elapsed: 0.27s, reconstruction error: 241.66
# Epoch 20:	########################################	elapsed: 0.23s, reconstruction error: 256.42
# Epoch 21:	########################################	elapsed: 0.27s, reconstruction error: 246.95
# Epoch 22:	########################################	elapsed: 0.29s, reconstruction error: 248.37
# Epoch 23:	########################################	elapsed: 0.24s, reconstruction error: 240.52
# Epoch 24:	########################################	elapsed: 0.27s, reconstruction error: 241.39
# Epoch 25:	########################################	elapsed: 0.32s, reconstruction error: 256.04
# Epoch 26:	########################################	elapsed: 0.30s, reconstruction error: 252.82
# Epoch 27:	########################################	elapsed: 0.31s, reconstruction error: 249.55
# Epoch 28:	########################################	elapsed: 0.29s, reconstruction error: 255.02
# Epoch 29:	########################################	elapsed: 0.32s, reconstruction error: 247.35
# Epoch 30:	########################################	elapsed: 0.35s, reconstruction error: 252.30
# Epoch 31:	########################################	elapsed: 0.33s, reconstruction error: 256.52
# Epoch 32:	########################################	elapsed: 0.35s, reconstruction error: 245.45
# Epoch 33:	########################################	elapsed: 0.32s, reconstruction error: 236.90
# Epoch 34:	########################################	elapsed: 0.34s, reconstruction error: 253.33
# Epoch 35:	########################################	elapsed: 0.33s, reconstruction error: 249.36
# Epoch 36:	########################################	elapsed: 0.37s, reconstruction error: 249.05
# Epoch 37:	########################################	elapsed: 0.33s, reconstruction error: 247.07
# Epoch 38:	########################################	elapsed: 0.33s, reconstruction error: 247.31
# Epoch 39:	########################################	elapsed: 0.33s, reconstruction error: 240.17
# Epoch 40:	########################################	elapsed: 0.35s, reconstruction error: 240.70
# Epoch 41:	########################################	elapsed: 0.36s, reconstruction error: 250.33
# Epoch 42:	########################################	elapsed: 0.34s, reconstruction error: 244.61
# Epoch 43:	########################################	elapsed: 0.35s, reconstruction error: 243.01
# Epoch 44:	########################################	elapsed: 0.33s, reconstruction error: 234.34
# Epoch 45:	########################################	elapsed: 0.33s, reconstruction error: 230.58
# Epoch 46:	########################################	elapsed: 0.36s, reconstruction error: 246.49
# Epoch 47:	########################################	elapsed: 0.37s, reconstruction error: 240.24
# Epoch 48:	########################################	elapsed: 0.35s, reconstruction error: 241.54
# Epoch 49:	########################################	elapsed: 0.36s, reconstruction error: 242.05
# Epoch 50:	########################################	elapsed: 0.33s, reconstruction error: 249.56
#
# Learning layer 3
# Epoch 1:	########################################	elapsed: 0.42s, reconstruction error: 60.28
# Epoch 2:	########################################	elapsed: 0.44s, reconstruction error: 53.29
# Epoch 3:	########################################	elapsed: 0.47s, reconstruction error: 59.67
# Epoch 4:	########################################	elapsed: 0.46s, reconstruction error: 64.61
# Epoch 5:	########################################	elapsed: 0.45s, reconstruction error: 71.48
# Epoch 6:	########################################	elapsed: 0.43s, reconstruction error: 105.51
# Epoch 7:	########################################	elapsed: 0.44s, reconstruction error: 124.41
# Epoch 8:	########################################	elapsed: 0.44s, reconstruction error: 133.94
# Epoch 9:	########################################	elapsed: 0.42s, reconstruction error: 134.98
# Epoch 10:	########################################	elapsed: 0.43s, reconstruction error: 143.40
# Epoch 11:	########################################	elapsed: 0.44s, reconstruction error: 142.70
# Epoch 12:	########################################	elapsed: 0.45s, reconstruction error: 144.56
# Epoch 13:	########################################	elapsed: 0.43s, reconstruction error: 144.02
# Epoch 14:	########################################	elapsed: 0.44s, reconstruction error: 142.07
# Epoch 15:	########################################	elapsed: 0.42s, reconstruction error: 149.92
# Epoch 16:	########################################	elapsed: 0.44s, reconstruction error: 144.56
# Epoch 17:	########################################	elapsed: 0.44s, reconstruction error: 147.04
# Epoch 18:	########################################	elapsed: 0.39s, reconstruction error: 156.02
# Epoch 19:	########################################	elapsed: 0.38s, reconstruction error: 154.25
# Epoch 20:	########################################	elapsed: 0.42s, reconstruction error: 156.02
# Epoch 21:	########################################	elapsed: 0.41s, reconstruction error: 143.76
# Epoch 22:	########################################	elapsed: 0.40s, reconstruction error: 150.69
# Epoch 23:	########################################	elapsed: 0.40s, reconstruction error: 147.86
# Epoch 24:	########################################	elapsed: 0.42s, reconstruction error: 145.95
# Epoch 25:	########################################	elapsed: 0.46s, reconstruction error: 145.92
# Epoch 26:	########################################	elapsed: 0.39s, reconstruction error: 146.80
# Epoch 27:	########################################	elapsed: 0.48s, reconstruction error: 158.94
# Epoch 28:	########################################	elapsed: 0.42s, reconstruction error: 149.35
# Epoch 29:	########################################	elapsed: 0.39s, reconstruction error: 148.12
# Epoch 30:	########################################	elapsed: 0.41s, reconstruction error: 154.16
# Epoch 31:	########################################	elapsed: 0.41s, reconstruction error: 145.19
# Epoch 32:	########################################	elapsed: 0.39s, reconstruction error: 144.70
# Epoch 33:	########################################	elapsed: 0.38s, reconstruction error: 146.69
# Epoch 34:	########################################	elapsed: 0.40s, reconstruction error: 142.53
# Epoch 35:	########################################	elapsed: 0.41s, reconstruction error: 144.44
# Epoch 36:	########################################	elapsed: 0.44s, reconstruction error: 151.15
# Epoch 37:	########################################	elapsed: 0.39s, reconstruction error: 148.82
# Epoch 38:	########################################	elapsed: 0.39s, reconstruction error: 145.13
# Epoch 39:	########################################	elapsed: 0.47s, reconstruction error: 139.70
# Epoch 40:	########################################	elapsed: 0.50s, reconstruction error: 146.68
# Epoch 41:	########################################	elapsed: 0.48s, reconstruction error: 146.09
# Epoch 42:	########################################	elapsed: 0.42s, reconstruction error: 145.64
# Epoch 43:	########################################	elapsed: 0.43s, reconstruction error: 143.80
# Epoch 44:	########################################	elapsed: 0.47s, reconstruction error: 146.11
# Epoch 45:	########################################	elapsed: 0.46s, reconstruction error: 144.24
# Epoch 46:	########################################	elapsed: 0.45s, reconstruction error: 141.86
# Epoch 47:	########################################	elapsed: 0.39s, reconstruction error: 147.86
# Epoch 48:	########################################	elapsed: 0.48s, reconstruction error: 141.73
# Epoch 49:	########################################	elapsed: 0.47s, reconstruction error: 145.49
# Epoch 50:	########################################	elapsed: 0.46s, reconstruction error: 145.93
# <h3>Finetuning pretrained MLP</h3>
# Epoch 1:	########################################	elapsed: 0.86s, accuracy: 93.67
# Epoch 2:	########################################	elapsed: 0.89s, accuracy: 94.18
# Epoch 3:	########################################	elapsed: 0.81s, accuracy: 95.87
# Epoch 4:	########################################	elapsed: 0.88s, accuracy: 95.97
# Epoch 5:	########################################	elapsed: 0.82s, accuracy: 96.24
# Epoch 6:	########################################	elapsed: 0.83s, accuracy: 96.14
# Epoch 7:	########################################	elapsed: 0.77s, accuracy: 96.26
# Epoch 8:	########################################	elapsed: 0.81s, accuracy: 95.88
# Epoch 9:	########################################	elapsed: 0.79s, accuracy: 96.61
# Epoch 10:	########################################	elapsed: 0.77s, accuracy: 96.65
# Epoch 11:	########################################	elapsed: 0.81s, accuracy: 96.70
# Epoch 12:	########################################	elapsed: 0.79s, accuracy: 96.97
# Epoch 13:	########################################	elapsed: 0.81s, accuracy: 96.91
# Epoch 14:	########################################	elapsed: 0.86s, accuracy: 96.99
# Epoch 15:	########################################	elapsed: 0.80s, accuracy: 96.95
# Epoch 16:	########################################	elapsed: 0.90s, accuracy: 96.96
# Epoch 17:	########################################	elapsed: 0.82s, accuracy: 96.94
# Epoch 18:	########################################	elapsed: 0.91s, accuracy: 96.94
# Epoch 19:	########################################	elapsed: 0.77s, accuracy: 96.93
# Epoch 20:	########################################	elapsed: 0.84s, accuracy: 96.93
# Epoch 21:	########################################	elapsed: 0.82s, accuracy: 96.93
# Epoch 22:	########################################	elapsed: 0.84s, accuracy: 96.93
# Epoch 23:	########################################	elapsed: 0.92s, accuracy: 96.92
# Epoch 24:	########################################	elapsed: 0.91s, accuracy: 96.91
# Epoch 25:	########################################	elapsed: 0.89s, accuracy: 96.90
# Epoch 26:	########################################	elapsed: 0.85s, accuracy: 96.91
# Epoch 27:	########################################	elapsed: 0.94s, accuracy: 96.90
# Epoch 28:	########################################	elapsed: 0.91s, accuracy: 96.90
# Epoch 29:	########################################	elapsed: 0.92s, accuracy: 96.90
# Epoch 30:	########################################	elapsed: 0.94s, accuracy: 96.90
# Epoch 31:	########################################	elapsed: 0.96s, accuracy: 96.90
# Epoch 32:	########################################	elapsed: 0.92s, accuracy: 96.90
# Epoch 33:	########################################	elapsed: 0.88s, accuracy: 96.89
# Epoch 34:	########################################	elapsed: 0.87s, accuracy: 96.91
# Epoch 35:	########################################	elapsed: 0.93s, accuracy: 96.90
# Epoch 36:	########################################	elapsed: 0.92s, accuracy: 96.90
# Epoch 37:	########################################	elapsed: 0.92s, accuracy: 96.91
# Epoch 38:	########################################	elapsed: 0.83s, accuracy: 96.91
# Epoch 39:	########################################	elapsed: 0.85s, accuracy: 96.91
# Epoch 40:	########################################	elapsed: 0.85s, accuracy: 96.91
# Epoch 41:	########################################	elapsed: 0.87s, accuracy: 96.91
# Epoch 42:	########################################	elapsed: 0.91s, accuracy: 96.91
# Epoch 43:	########################################	elapsed: 0.91s, accuracy: 96.91
# Epoch 44:	########################################	elapsed: 0.82s, accuracy: 96.92
# Epoch 45:	########################################	elapsed: 0.92s, accuracy: 96.92
# Epoch 46:	########################################	elapsed: 0.90s, accuracy: 96.92
# Epoch 47:	########################################	elapsed: 0.90s, accuracy: 96.92
# Epoch 48:	########################################	elapsed: 0.87s, accuracy: 96.93
# Epoch 49:	########################################	elapsed: 0.85s, accuracy: 96.92
# Epoch 50:	########################################	elapsed: 0.84s, accuracy: 96.93
# Training finished!
# <h3>First layer filters in the DBN</h3>
# <h3>Input layer filters in the pretrained & finetuned MLP</h3>
# <h3>Largest norms of weight-vectors in the finetuned MLP layers</h3>
# 	layer 1: 2.00
# 	layer 2: 1.00
# 	layer 3: 1.00
# 	layer 4: 4.00
